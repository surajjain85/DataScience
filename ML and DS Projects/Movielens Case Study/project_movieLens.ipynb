# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings(action="ignore")

# %%
movies=pd.read_csv("movies.dat",sep="::",header=None,names=["MovieID", "MovieName", "Genres"])
ratings=pd.read_csv("ratings.dat", sep="::", header=None, names=["UserID", "MovieID", "Rating", "Timestamp"])
users = pd.read_csv("users.dat", sep="::", names = ["UserID", "Gender", "Age", "Occupation", "ZipCode"])

# %%
print(movies[:2], "\n\n", ratings[:2],"\n\n",users[:2])
# Out:
#    MovieID         MovieName                        Genres
# 0        1  Toy Story (1995)   Animation|Children's|Comedy
# 1        2    Jumanji (1995)  Adventure|Children's|Fantasy
#
#     UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
#
#     UserID Gender  Age  Occupation ZipCode
# 0       1      F    1          10   48067
# 1       2      M   56          16   70072

# %%
movies.shape, ratings.shape, users.shape
# Out:
# ((3883, 3), (1000209, 4), (6040, 5))

# %%
movie_ratings = pd.merge(movies, ratings, on="MovieID")
movie_ratings.shape
# Out:
# (1000209, 6)

# %%
print (movie_ratings[:2], "\n\n", users[:2])
# Out:
#    MovieID         MovieName                       Genres  UserID  Rating  \
# 0        1  Toy Story (1995)  Animation|Children's|Comedy       1       5
# 1        1  Toy Story (1995)  Animation|Children's|Comedy       6       4
#
#    Timestamp
# 0  978824268
# 1  978237008
#
#     UserID Gender  Age  Occupation ZipCode
# 0       1      F    1          10   48067
# 1       2      M   56          16   70072

# %%
combinedData= pd.merge(movie_ratings,users,on="UserID")

# %%
combinedData.shape
# Out:
# (1000209, 10)

# %%
#we have large data so we'll shuffle and will work on 5000 records
np.random.seed(19)
combineddata=combineddata.iloc[np.random.permutation(combinedData.shape[0]), :]

# %%
combinedData = combinedData[:5000]

# %%
combinedData.head(5000)
# Out:
#       MovieID                                  MovieName  \
# 0           1                           Toy Story (1995)
# 1          48                          Pocahontas (1995)
# 2         150                           Apollo 13 (1995)
# 3         260  Star Wars: Episode IV - A New Hope (1977)
# 4         527                    Schindler's List (1993)
# ...       ...                                        ...
# 4995     3549                      Guys and Dolls (1955)
# 4996     3599                      Anchors Aweigh (1945)
# 4997     3600                         Blue Hawaii (1961)
# 4998     3606                         On the Town (1949)
# 4999     3614                  Honeymoon in Vegas (1992)
#
#                                     Genres  UserID  Rating  Timestamp Gender  \
# 0              Animation|Children's|Comedy       1       5  978824268      F
# 1     Animation|Children's|Musical|Romance       1       5  978824351      F
# ...

# %%
Genre= combinedData['Genres']

# %%
Genre = Genre.str.get_dummies().add_prefix('Genre_')
Genre
# Out:
#       Genre_Action  Genre_Adventure  Genre_Animation  Genre_Children's  \
# 0                0                0                1                 1
# 1                0                0                1                 1
# 2                0                0                0                 0
# 3                1                1                0                 0
# 4                0                0                0                 0
# ...            ...              ...              ...               ...
# 4995             0                0                0                 0
# 4996             0                0                0                 0
# 4997             0                0                0                 0
# 4998             0                0                0                 0
# 4999             0                0                0                 0
#
#       Genre_Comedy  Genre_Crime  Genre_Documentary  Genre_Drama  \
# ...

# %%
movie_ratings_genres_df = pd.concat([combinedData.drop(['Genres'],axis=1),
     Genre],
    axis=1
)

movie_ratings_genres_df.head()
# Out:
#    MovieID                                  MovieName  UserID  Rating  \
# 0        1                           Toy Story (1995)       1       5
# 1       48                          Pocahontas (1995)       1       5
# 2      150                           Apollo 13 (1995)       1       5
# 3      260  Star Wars: Episode IV - A New Hope (1977)       1       4
# 4      527                    Schindler's List (1993)       1       5
#
#    Timestamp Gender  Age  Occupation ZipCode  Genre_Action  ...  \
# 0  978824268      F    1          10   48067             0  ...
# 1  978824351      F    1          10   48067             0  ...
# 2  978301777      F    1          10   48067             0  ...
# 3  978300760      F    1          10   48067             1  ...
# 4  978824195      F    1          10   48067             0  ...
#
#    Genre_Fantasy  Genre_Film-Noir  Genre_Horror  Genre_Musical  Genre_Mystery  \
# ...
